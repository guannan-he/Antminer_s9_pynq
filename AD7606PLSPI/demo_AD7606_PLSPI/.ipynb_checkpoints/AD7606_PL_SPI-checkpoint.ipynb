# %%
# %matplotlib inline
from pynq import Overlay
from pynq.lib import AxiGPIO
import time
import numpy as np
import matplotlib.pyplot as plt

# %%
GPIO = Overlay('AD7606PLSPI.bit')

# %% [markdown]
# miner0[0:3] -- OS0[0:3]
# miner0[3]  --  RST

# %% [markdown]
# miner1[0:2] -- STA, STB
# miner1[2]  --  BUSY

# %% [markdown]
# miner2[0] -- clk
# miner2[1:3]-- db78
# miner2[3] -- cs

# %%
miner_instance_0 = GPIO.ip_dict["plMiner0"]
miner_instance_1 = GPIO.ip_dict["plMiner1"]
AD7606_instance = GPIO.ip_dict["AD7606_PL_SPI.ipynb"]
miner0 = AxiGPIO(miner_instance_0).channel1  # 数字滤波器， 复位
miner1 = AxiGPIO(miner_instance_1).channel1  # 转换控制， busy
AD7606 = AxiGPIO(AD7606_instance).channel1  # spi口
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-190d576e7342> in <module>()
#       1 miner_instance_0 = GPIO.ip_dict["plMiner0"]
#       2 miner_instance_1 = GPIO.ip_dict["plMiner1"]
# ----> 3 AD7606_instance = GPIO.ip_dict["AD7606_PL_SPI.ipynb"]
#       4 miner0 = AxiGPIO(miner_instance_0).channel1  # 数字滤波器， 复位
#       5 miner1 = AxiGPIO(miner_instance_1).channel1  # 转换控制， busy
#
# /usr/local/lib/python3.6/dist-packages/pynq/utils.py in __getitem__(self, key)
#     864
#     865     def __getitem__(self, key):
# --> 866         obj = super().__getitem__(key)
#     867         if type(obj) is dict:
#     868             return ReprDict(obj, expanded=self._expanded, rootname=key)
#
# KeyError: 'AD7606_PL_SPI.ipynb'

# %%
def GPIOreset(val = 0xff):
    if val == 0:
        miner0.trimask = 0xf;
    elif val == 1:
        miner1.trimask = 0xf;
    elif val == 2:
        miner2.trimask = 0xf;
    else:
        miner0.trimask = 0xf;
        miner1.trimask = 0xf;
        miner2.trimask = 0xf;

# %%
def AD7606_SETOS(val = 0x00):  # 数字滤波器设置
    miner0[0:3].write(val & 0x7)

# %%
def AD7606_RESET():  # 重置AD7606
    miner0[3].on()
    time.sleep(0.05)
    miner0[3].off()

# %%
def AD7606_BUSY():  # 获取是否正在转换
    status = (miner1.read() & 0x04)
#     status = np.bitwise_and(miner1.read(), 0x04)
    return status

# %%
def AD7606_STARTCONV():  # 开始转换指令
    miner1[0:2].off()
#     time.sleep(0.0001)
    miner1[0:2].on()

# %%
def AD7606_FREEZECONV():  # 拉高待机
    miner1[0:2].on()

# %%
def AD7606_CS_L():  # 片选
    miner2[3].off()

# %%
def AD7606_CS_H():  # 取消片选
    miner2[3].on()

# %%
def AD7606_SCLK_L():  # 时钟拉低
    miner2[0].off()

# %%
def AD7606_SCLK_H():  # 时钟拉高
    miner2[0].on()

# %%
def ad7606_ReadBytes():  # 读取一个通道数值
    val = 0
    for i in range(16):
#         AD7606_SCLK_L()
        miner2[0].off()
        val = val * 2
        if (miner2.read() & 0x02):
            val = val + 1
#             val = np.bitwise_or(val, 0x0001)
#         AD7606_SCLK_H()
        miner2[0].on()
    return val

# %%
GPIOreset()  # 恢复所有端口为高阻
AD7606_SETOS(0x00)
AD7606_RESET()
AD7606_FREEZECONV()

# %%
# 时钟拉高待命
AD7606_CS_H()
AD7606_SCLK_H()

# %%
data = np.zeros((8, 100))

# %% [markdown]
# # 测试
# AD7606_STARTCONV()
# while AD7606_BUSY():
#         pass
# for i in range(8):
#     AD7606_CS_L()
#     tmp = ad7606_ReadBytes()
#     AD7606_CS_H()
#     print(tmp)

# %%
time_start = time.time()
for k in range(100):  # 采集100个点
    AD7606_STARTCONV()
    while AD7606_BUSY():
        pass
    for i in range(8):
        AD7606_CS_L()
        tmp = ad7606_ReadBytes()
        data[i, k] = tmp
        AD7606_CS_H()
#         print(tmp)
totalTime = time.time() - time_start
print(f"耗时{totalTime}秒")
# Out:
# 耗时5.237017393112183秒

# %%
t = np.linspace(0,totalTime,100)
data = data / 6553
canvas = plt.gcf()
canvas.set_size_inches((12,6))
for i in range(8):
    plt.subplot(2, 4, i + 1)
    plt.plot(t, data[i, :])
plt.show()
